# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
df = pd.read_csv("phase1_aadhaar_pressure_metrics_FINAL.csv")
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(['pincode', 'date']).reset_index(drop=True)
df.head(50)
# Out:
#          date   state       district  pincode  total_enrollments  \
# 0  2025-09-02  100000         100000   100000                3.0
# 1  2025-09-03  100000         100000   100000                1.0
# 2  2025-09-08  100000         100000   100000                1.0
# 3  2025-09-09  100000         100000   100000                1.0
# 4  2025-09-11  100000         100000   100000                2.0
# 5  2025-09-12  100000         100000   100000                2.0
# 6  2025-09-19  100000         100000   100000                1.0
# 7  2025-09-20  100000         100000   100000                1.0
# 8  2025-10-24  100000         100000   100000                1.0
# 9  2025-11-15  100000         100000   100000                3.0
# 10 2025-11-16  100000         100000   100000                2.0
# 11 2025-11-17  100000         100000   100000                4.0
# 12 2025-11-19  100000         100000   100000                2.0
# 13 2025-12-15  100000         100000   100000              161.0
# 14 2025-12-20  100000         100000   100000                0.0
# 15 2025-12-23  100000         100000   100000                0.0
# 16 2025-12-24  100000         100000   100000                1.0
# 17 2025-12-25  100000         100000   100000                4.0
# 18 2025-12-26  100000         100000   100000                3.0
# 19 2025-12-27  100000         100000   100000                4.0
# 20 2025-12-27  100000         100000   100000                4.0
# 21 2025-12-28  100000         100000   100000                5.0
# 22 2025-12-29  100000         100000   100000                8.0
# 23 2025-12-31  100000         100000   100000                4.0
# 24 2025-03-01   Delhi  Central Delhi   110001                0.0
# 25 2025-03-01   Delhi      New Delhi   110001                0.0
# 26 2025-03-01   Delhi      New Delhi   110001                0.0
# 27 2025-04-01   Delhi      New Delhi   110001                0.0
# 28 2025-05-01   Delhi      New Delhi   110001                0.0
# 29 2025-06-01   Delhi      New Delhi   110001                0.0
# 30 2025-07-01   Delhi      New Delhi   110001                0.0
# 31 2025-09-01   Delhi  Central Delhi   110001                1.0
# 32 2025-09-01   Delhi  Central Delhi   110001                1.0
# 33 2025-09-01   Delhi      New Delhi   110001                2.0
# 34 2025-09-02   Delhi  Central Delhi   110001                0.0
# 35 2025-09-02   Delhi      New Delhi   110001                2.0
# 36 2025-09-03   Delhi  Central Delhi   110001                1.0
# 37 2025-09-03   Delhi      New Delhi   110001                0.0
# 38 2025-09-03   Delhi      New Delhi   110001                0.0
# 39 2025-09-04   Delhi  Central Delhi   110001                0.0
# 40 2025-09-04   Delhi      New Delhi   110001                0.0
# 41 2025-09-05   Delhi      New Delhi   110001                0.0
# 42 2025-09-06   Delhi  Central Delhi   110001                0.0
# 43 2025-09-06   Delhi  Central Delhi   110001                0.0
# 44 2025-09-06   Delhi      New Delhi   110001                2.0
# 45 2025-09-07   Delhi      New Delhi   110001                0.0
# 46 2025-09-08   Delhi  Central Delhi   110001                0.0
# 47 2025-09-08   Delhi      New Delhi   110001                0.0
# 48 2025-09-08   Delhi      New Delhi   110001                0.0
# 49 2025-09-09   Delhi  Central Delhi   110001                0.0
#
#     total_demo_updates  total_bio_updates        atpi         dvi         bsi  \
# 0                  0.0                0.0    0.000000    0.000000    0.000000
# 1                  0.0                0.0    0.000000    0.000000    0.000000
# 2                  0.0                0.0    0.000000    0.000000    0.000000
# 3                  0.0                0.0    0.000000    0.000000    0.000000
# 4                  0.0                0.0    0.000000    0.000000    0.000000
# 20             1.609438            0.038849             Normal
# 21             1.791759            0.043250             Normal
# 22             2.197225            0.053038             Normal
# 23             1.609438            0.038849             Normal
# 24             0.000000            0.258037  Critical Overload
# 25             0.000000            0.372940  Critical Overload
# 26             0.000000            0.372940  Critical Overload
# 27             0.000000            0.334593  Critical Overload
# 28             0.000000            0.321771  Critical Overload
# 29             0.000000            0.358152  Critical Overload
# 30             0.000000            0.329429  Critical Overload
# 31             0.693147            0.094827             Normal
# 32             0.693147            0.094827             Normal
# 33             1.098612            0.143603    Emerging Stress
# 34             0.000000            0.038260             Normal
# 35             1.098612            0.127314    Emerging Stress
# 36             0.693147            0.072653             Normal
# 37             0.000000            0.159783    Emerging Stress
# 38             0.000000            0.159783    Emerging Stress
# 39             0.000000            0.099289             Normal
# 40             0.000000            0.196939  Critical Overload
# 41             0.000000            0.107558             Normal
# 42             0.000000            0.115231    Emerging Stress
# 43             0.000000            0.115231    Emerging Stress
# 44             1.098612            0.123392    Emerging Stress
# 45             0.000000            0.038923             Normal
# 46             0.000000            0.077847             Normal
# 47             0.000000            0.184354  Critical Overload
# 48             0.000000            0.184354  Critical Overload
# 49             0.000000            0.089326             Normal

# %%
df['load_delta'] = (
    df.groupby('pincode')['aadhaar_load_score']
      .diff()
      .fillna(0)
)

# %%
df['load_rolling_mean'] = (
    df.groupby('pincode')['aadhaar_load_score']
      .rolling(7, min_periods=1)
      .mean()
      .reset_index(level=0, drop=True)
)

df['load_rolling_std'] = (
    df.groupby('pincode')['aadhaar_load_score']
      .rolling(7, min_periods=1)
      .std()
      .fillna(0)
      .reset_index(level=0, drop=True)
)

# %%
df['z_score'] = (
    (df['aadhaar_load_score'] - df['load_rolling_mean']) /
    (df['load_rolling_std'] + 1e-6)
)

df['spike_anomaly'] = df['z_score'].abs() > 3

# %%
pop_median = df['population_pressure'].median()

df['silent_failure'] = (
    (df['aadhaar_load_score'] < df['load_rolling_mean'] * 0.3) &
    (df['population_pressure'] > df['population_pressure'].quantile(0.6)) &
    (df['load_rolling_mean'] > df['aadhaar_load_score'].quantile(0.5))
)

# %%
features = df[
    [
        'aadhaar_load_score',
        'load_delta',
        'atpi',
        'dvi',
        'bsi',
        'population_pressure'
    ]
].fillna(0)
iso = IsolationForest(
    n_estimators=300,
    contamination=0.07,
    random_state=42
)

df['iforest_flag'] = iso.fit_predict(features)
df['iforest_anomaly'] = df['iforest_flag'] == -1

# %%
df['anomaly_type'] = 'Normal'

df.loc[df['silent_failure'], 'anomaly_type'] = 'Silent Service Failure'
df.loc[df['spike_anomaly'], 'anomaly_type'] = 'Sudden Overload Spike'
df.loc[df['iforest_anomaly'], 'anomaly_type'] = 'Structural Anomaly'

# %%
df['anomaly_severity'] = 'None'

df.loc[df['z_score'].abs() > 4, 'anomaly_severity'] = 'Critical'
df.loc[df['z_score'].abs().between(2.5, 4), 'anomaly_severity'] = 'High'
df.loc[df['silent_failure'], 'anomaly_severity'] = 'Medium'
df.loc[df['iforest_anomaly'], 'anomaly_severity'] = 'Medium'

# %%
phase2_cols = [
    'date', 'state', 'district', 'pincode',
    'aadhaar_load_score', 'load_status',
    'z_score', 'load_delta',
    'anomaly_type', 'anomaly_severity'
]

phase2_df = df[phase2_cols]
phase2_df.head(50)
# Out:
# 9              Normal  1.680121    0.016732              Normal
# 10             Normal  0.482907   -0.006944              Normal
# 11             Normal  1.550717    0.012331              Normal
# 12             Normal  0.162263   -0.012331              Normal
# 13    Emerging Stress  2.213859    0.096288  Structural Anomaly
# 14             Normal -0.140576   -0.084547              Normal
# 15             Normal -0.238036    0.000000              Normal
# 16             Normal -0.763049   -0.021529              Normal
# 17             Normal -0.197168    0.022118              Normal
# 18             Normal -0.326814   -0.005386              Normal
# 19             Normal -0.229039    0.005386              Normal
# 20             Normal  0.500913    0.000000              Normal
# 21             Normal  0.891269    0.004401              Normal
# 22             Normal  1.404011    0.009787              Normal
# 23             Normal -0.308100   -0.014188              Normal
# 24  Critical Overload  0.000000    0.000000              Normal
# 25  Critical Overload  0.707098    0.114903  Structural Anomaly
# 26  Critical Overload  0.577342    0.000000  Structural Anomaly
# 27  Critical Overload -0.000642   -0.038347  Structural Anomaly
# 28  Critical Overload -0.217621   -0.012821  Structural Anomaly
# 29  Critical Overload  0.498835    0.036380  Structural Anomaly
# 30  Critical Overload -0.149936   -0.028722  Structural Anomaly
# 31             Normal -2.216842   -0.234602              Normal
# 32             Normal -1.448887    0.000000              Normal
# 33    Emerging Stress -0.788047    0.048777              Normal
# 34             Normal -1.185141   -0.105343              Normal
# 35    Emerging Stress -0.340589    0.089054              Normal
# 36             Normal -0.590084   -0.054661              Normal
# 37    Emerging Stress  1.310180    0.087130              Normal
# 38    Emerging Stress  0.986770    0.000000              Normal
# 39             Normal -0.325436   -0.060494              Normal
# 40  Critical Overload  1.350865    0.097649              Normal
# 41             Normal -0.569282   -0.089381              Normal
# 42    Emerging Stress -0.345795    0.007673              Normal
# 43    Emerging Stress -0.580841    0.000000              Normal
# 44    Emerging Stress -0.220038    0.008161              Normal
# 45             Normal -1.616926   -0.084469              Normal
# 46             Normal -0.683690    0.038923              Normal
# 47  Critical Overload  1.697316    0.106507              Normal
# 48  Critical Overload  1.221960    0.000000              Normal
# 49             Normal -0.497559   -0.095027              Normal
#
#    anomaly_severity
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7              None
# 8              None
# 9              None
# 10             None
# 11             None
# 12             None
# 13           Medium
# 14             None
# 15             None
# 16             None
# 17             None
# 18             None
# 19             None
# 20             None
# 21             None
# 22             None
# 23             None
# 24             None
# 25           Medium
# 26           Medium
# 27           Medium
# 28           Medium
# 29           Medium
# 30           Medium
# 31             None
# 32             None
# 33             None
# 34             None
# 35             None
# 36             None
# 37             None
# 38             None
# 39             None
# 40             None
# 41             None
# 42             None
# 43             None
# 44             None
# 45             None
# 46             None
# 47             None
# 48             None
# 49             None

# %%
phase2_df.to_csv(
    "phase2_aadhaar_anomaly_detection_final.csv",
    index=False
)

print("✅ Phase 2 anomaly detection CSV exported successfully")
# Out:
# ✅ Phase 2 anomaly detection CSV exported successfully

# %%
phase2_df['anomaly_severity'].value_counts(normalize=True)
# Out:
# anomaly_severity
# None      0.925989
# Medium    0.074011
# Name: proportion, dtype: float64

# %%
phase2_df['anomaly_type'].value_counts(normalize=True)
# Out:
# anomaly_type
# Normal                    0.925989
# Structural Anomaly        0.069995
# Silent Service Failure    0.004016
# Name: proportion, dtype: float64

# %%
phase2_df = phase2_df ['state'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 phase2_df = phase2_df ['state'].nunique()
#
# NameError: name 'phase2_df' is not defined
