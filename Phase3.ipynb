# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
df = pd.read_csv("phase2_aadhaar_anomaly_detection_final.csv")
df['date'] = pd.to_datetime(df['date'])
df['anomaly_severity'] = df['anomaly_severity'].fillna('None')

df.head(25)
# Out:
#          date   state       district  pincode  aadhaar_load_score  \
# 0  2025-09-02  100000         100000   100000            0.033463
# 1  2025-09-03  100000         100000   100000            0.016732
# 2  2025-09-08  100000         100000   100000            0.016732
# 3  2025-09-09  100000         100000   100000            0.016732
# 4  2025-09-11  100000         100000   100000            0.026519
# 5  2025-09-12  100000         100000   100000            0.026519
# 6  2025-09-19  100000         100000   100000            0.016732
# 7  2025-09-20  100000         100000   100000            0.016732
# 8  2025-10-24  100000         100000   100000            0.016732
# 9  2025-11-15  100000         100000   100000            0.033463
# 10 2025-11-16  100000         100000   100000            0.026519
# 11 2025-11-17  100000         100000   100000            0.038849
# 12 2025-11-19  100000         100000   100000            0.026519
# 13 2025-12-15  100000         100000   100000            0.122807
# 14 2025-12-20  100000         100000   100000            0.038260
# 15 2025-12-23  100000         100000   100000            0.038260
# 16 2025-12-24  100000         100000   100000            0.016732
# 17 2025-12-25  100000         100000   100000            0.038849
# 18 2025-12-26  100000         100000   100000            0.033463
# 19 2025-12-27  100000         100000   100000            0.038849
# 20 2025-12-27  100000         100000   100000            0.038849
# 21 2025-12-28  100000         100000   100000            0.043250
# 22 2025-12-29  100000         100000   100000            0.053038
# 23 2025-12-31  100000         100000   100000            0.038849
# 24 2025-03-01   Delhi  Central Delhi   110001            0.258037
#
#           load_status   z_score  load_delta        anomaly_type  \
# 0              Normal  0.000000    0.000000              Normal
# 1              Normal -0.707047   -0.016732              Normal
# 2              Normal -0.577291    0.000000              Normal
# 3              Normal -0.499940    0.000000              Normal
# 4              Normal  0.584766    0.009787              Normal
# 5              Normal  0.526386    0.000000              Normal
# 6              Normal -0.754799   -0.009787              Normal
# 7              Normal -0.585417    0.000000              Normal
# 8              Normal -0.585417    0.000000              Normal
# 9              Normal  1.680121    0.016732              Normal
# 10             Normal  0.482907   -0.006944              Normal
# 11             Normal  1.550717    0.012331              Normal
# 12             Normal  0.162263   -0.012331              Normal
# 13    Emerging Stress  2.213859    0.096288  Structural Anomaly
# 14             Normal -0.140576   -0.084547              Normal
# 15             Normal -0.238036    0.000000              Normal
# 16             Normal -0.763049   -0.021529              Normal
# 17             Normal -0.197168    0.022118              Normal
# 18             Normal -0.326814   -0.005386              Normal
# 19             Normal -0.229039    0.005386              Normal
# 20             Normal  0.500913    0.000000              Normal
# 21             Normal  0.891269    0.004401              Normal
# 22             Normal  1.404011    0.009787              Normal
# 23             Normal -0.308100   -0.014188              Normal
# 24  Critical Overload  0.000000    0.000000              Normal
#
#    anomaly_severity
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7              None
# 8              None
# 9              None
# 10             None
# 11             None
# 12             None
# 13           Medium
# 14             None
# 15             None
# 16             None
# 17             None
# 18             None
# 19             None
# 20             None
# 21             None
# 22             None
# 23             None
# 24             None

# %%
df['state'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['state'].nunique()
#
# NameError: name 'df' is not defined

# %%
df = df.sort_values(['pincode', 'date']).reset_index(drop=True)
df['t'] = df.groupby('pincode').cumcount()
pin_counts = df.groupby('pincode').size()
valid_pins = pin_counts[pin_counts >= 10].index

df_valid = df[df['pincode'].isin(valid_pins)]

# %%
def fast_forecast(pin_df, horizon=14):
    """
    Fast rolling trend-based forecast for Aadhaar load score
    """
    vals = pin_df['aadhaar_load_score'].values

    # Use last 7 observations (or fewer if not available)
    recent = vals[-7:]

    if len(recent) < 3:
        return None

    level = recent.mean()
    trend = np.diff(recent).mean()

    # Generate forecast
    forecast = [max(level + (i + 1) * trend, 0) for i in range(horizon)]

    return forecast

# %%
forecast_rows = []

for pin, g in df_valid.groupby('pincode'):
    g = g.sort_values('date')

    if len(g) < 5:
        continue

    fc = fast_forecast(g, horizon=14)

    if fc is None:
        continue

    for i, val in enumerate(fc):
        forecast_rows.append({
            'pincode': pin,
            'forecast_day': i + 1,
            'predicted_load_score': float(val)
        })

forecast_df = pd.DataFrame(forecast_rows)
forecast_df.head(42)
# Out:
#     pincode  forecast_day  predicted_load_score
# 0    100000             1              0.040736
# 1    100000             2              0.040736
# 2    100000             3              0.040736
# 3    100000             4              0.040736
# 4    100000             5              0.040736
# 5    100000             6              0.040736
# 6    100000             7              0.040736
# 7    100000             8              0.040736
# 8    100000             9              0.040736
# 9    100000            10              0.040736
# 10   100000            11              0.040736
# 11   100000            12              0.040736
# 12   100000            13              0.040736
# 13   100000            14              0.040736
# 14   110001             1              0.107220
# 15   110001             2              0.082808
# 16   110001             3              0.058395
# 17   110001             4              0.033982
# 18   110001             5              0.009569
# 19   110001             6              0.000000
# 20   110001             7              0.000000
# 21   110001             8              0.000000
# 22   110001             9              0.000000
# 23   110001            10              0.000000
# 24   110001            11              0.000000
# 25   110001            12              0.000000
# 26   110001            13              0.000000
# 27   110001            14              0.000000
# 28   110002             1              0.179521
# 29   110002             2              0.152912
# 30   110002             3              0.126304
# 31   110002             4              0.099695
# 32   110002             5              0.073087
# 33   110002             6              0.046478
# 34   110002             7              0.019869
# 35   110002             8              0.000000
# 36   110002             9              0.000000
# 37   110002            10              0.000000
# 38   110002            11              0.000000
# 39   110002            12              0.000000
# 40   110002            13              0.000000
# 41   110002            14              0.000000

# %%
forecast_df['predicted_load_status'] = np.select(
    [
        forecast_df['predicted_load_score'] <= p40,
        (forecast_df['predicted_load_score'] > p40) &
        (forecast_df['predicted_load_score'] <= p75),
        forecast_df['predicted_load_score'] > p75
    ],
    [
        'Normal',
        'Emerging Stress',
        'Critical Overload'
    ],
    default='Normal'   # 👈 IMPORTANT
)
forecast_df['predicted_load_status'].value_counts()
# Out:
# predicted_load_status
# Normal               225422
# Emerging Stress       34389
# Critical Overload     13637
# Name: count, dtype: int64

# %%
# Detect first future day when load becomes non-normal
stress_days = (
    forecast_df
        .loc[forecast_df['predicted_load_status'] != 'Normal']
        .groupby('pincode', as_index=False)['forecast_day']
        .min()
        .rename(columns={'forecast_day': 'stress_starts_in_days'})
)

stress_days.head(20)
# Out:
#     pincode  stress_starts_in_days
# 0    110002                      1
# 1    110005                      1
# 2    110006                      1
# 3    110007                      1
# 4    110008                      1
# 5    110009                      1
# 6    110010                      1
# 7    110011                      3
# 8    110012                      1
# 9    110013                      1
# 10   110014                      1
# 11   110015                      1
# 12   110017                      1
# 13   110018                      1
# 14   110019                      1
# 15   110020                      1
# 16   110021                      1
# 17   110022                      1
# 18   110024                      1
# 19   110025                      1

# %%
# Keep all anomalies
df_anom = df[df['anomaly_flag'] == True]

# Sample normal points (10x anomalies)
df_norm = df[df['anomaly_flag'] == False].sample(
    n=min(len(df_anom) * 10, len(df[df['anomaly_flag'] == False])),
    random_state=42
)

df_train = pd.concat([df_anom, df_norm]).sample(frac=1, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

X_train = df_train[
    [
        'aadhaar_load_score',
        'load_delta',
        'z_score'
    ]
].fillna(0)

y_train = df_train['anomaly_flag']

rf = RandomForestClassifier(
    n_estimators=80,      # ↓ from 200
    max_depth=4,          # ↓ from 5
    min_samples_leaf=50,  # regularization
    n_jobs=-1,            # parallelize
    random_state=42
)

rf.fit(X_train, y_train)

print("✅ Fast Random Forest anomaly model trained")
# Out:
# ✅ Fast Random Forest anomaly model trained

# %%
rf_input = pd.DataFrame({
    'aadhaar_load_score': forecast_df['predicted_load_score'],
    'load_delta': np.zeros(len(forecast_df)),
    'z_score': np.zeros(len(forecast_df))
})

forecast_df['anomaly_risk'] = rf.predict_proba(rf_input)[:, 1]
forecast_df[['pincode', 'forecast_day', 'anomaly_risk']].head(15)
# Out:
#     pincode  forecast_day  anomaly_risk
# 0    100000             1      0.084261
# 1    100000             2      0.084261
# 2    100000             3      0.084261
# 3    100000             4      0.084261
# 4    100000             5      0.084261
# 5    100000             6      0.084261
# 6    100000             7      0.084261
# 7    100000             8      0.084261
# 8    100000             9      0.084261
# 9    100000            10      0.084261
# 10   100000            11      0.084261
# 11   100000            12      0.084261
# 12   100000            13      0.084261
# 13   100000            14      0.084261
# 14   110001             1      0.084261

# %%
forecast_df['early_warning'] = (
    (forecast_df['predicted_load_status'] != 'Normal') |
    (forecast_df['anomaly_risk'] > 0.6)
)

# %%
phase3_final_df = forecast_df[
    [
        'pincode',
        'forecast_day',
        'predicted_load_score',
        'predicted_load_status',
        'anomaly_risk',
        'early_warning'
    ]
]

phase3_final_df.head(20)
# Out:
#     pincode  forecast_day  predicted_load_score predicted_load_status  \
# 0    100000             1              0.040736                Normal
# 1    100000             2              0.040736                Normal
# 2    100000             3              0.040736                Normal
# 3    100000             4              0.040736                Normal
# 4    100000             5              0.040736                Normal
# 5    100000             6              0.040736                Normal
# 6    100000             7              0.040736                Normal
# 7    100000             8              0.040736                Normal
# 8    100000             9              0.040736                Normal
# 9    100000            10              0.040736                Normal
# 10   100000            11              0.040736                Normal
# 11   100000            12              0.040736                Normal
# 12   100000            13              0.040736                Normal
# 13   100000            14              0.040736                Normal
# 14   110001             1              0.107220                Normal
# 15   110001             2              0.082808                Normal
# 16   110001             3              0.058395                Normal
# 17   110001             4              0.033982                Normal
# 18   110001             5              0.009569                Normal
# 19   110001             6              0.000000                Normal
#
#     anomaly_risk  early_warning
# 0       0.084261          False
# 1       0.084261          False
# 2       0.084261          False
# 3       0.084261          False
# 4       0.084261          False
# 5       0.084261          False
# 6       0.084261          False
# 7       0.084261          False
# 8       0.084261          False
# 9       0.084261          False
# 10      0.084261          False
# 11      0.084261          False
# 12      0.084261          False
# 13      0.084261          False
# 14      0.084261          False
# 15      0.084261          False
# 16      0.084261          False
# 17      0.086753          False
# 18      0.086753          False
# 19      0.086753          False

# %%
phase3_final_df.describe
# Out:
# <bound method NDFrame.describe of         pincode  forecast_day  predicted_load_score predicted_load_status  \
# 0        100000             1              0.040736                Normal
# 1        100000             2              0.040736                Normal
# 2        100000             3              0.040736                Normal
# 3        100000             4              0.040736                Normal
# 4        100000             5              0.040736                Normal
# ...         ...           ...                   ...                   ...
# 273443   855456            10              0.027327                Normal
# 273444   855456            11              0.023597                Normal
# 273445   855456            12              0.019867                Normal
# 273446   855456            13              0.016136                Normal
# 273447   855456            14              0.012406                Normal
#
#         anomaly_risk  early_warning
# 0           0.084261          False
# 1           0.084261          False
# 2           0.084261          False
# 3           0.084261          False
# 4           0.084261          False
# ...              ...            ...
# 273443      0.086753          False
# 273444      0.086753          False
# 273445      0.086753          False
# 273446      0.086753          False
# 273447      0.086753          False
#
# [273448 rows x 6 columns]>

# %%
phase3_final_df['early_warning'].value_counts()
# Out:
# early_warning
# False    225422
# True      48026
# Name: count, dtype: int64

# %%
early_warning_df = phase3_final_df[phase3_final_df['early_warning'] == True]
early_warning_df.head(10)
# Out:
#     pincode  forecast_day  predicted_load_score predicted_load_status  \
# 28   110002             1              0.179521     Critical Overload
# 29   110002             2              0.152912       Emerging Stress
# 30   110002             3              0.126304       Emerging Stress
# 70   110005             1              0.154187       Emerging Stress
# 71   110005             2              0.137683       Emerging Stress
# 72   110005             3              0.121180       Emerging Stress
# 84   110006             1              0.203313     Critical Overload
# 85   110006             2              0.178661     Critical Overload
# 86   110006             3              0.154009       Emerging Stress
# 87   110006             4              0.129356       Emerging Stress
#
#     anomaly_risk  early_warning
# 28      0.084261           True
# 29      0.084261           True
# 30      0.084261           True
# 70      0.084261           True
# 71      0.084261           True
# 72      0.084261           True
# 84      0.096066           True
# 85      0.084261           True
# 86      0.084261           True
# 87      0.084261           True

# %%
phase3_final_df.to_csv(
    "phase3_aadhaar_early_warning_final.csv",
    index=False
)

print("✅ Phase 3 early-warning dataset exported successfully")
# Out:
# ✅ Phase 3 early-warning dataset exported successfully
